# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# 作業1
# 1.Google Play商店應用，可以提前知道(使用者)的消費模式、興趣、消費能力、多少金額下不須考慮、多少金額需考慮，設樣企業就可以針對該(用戶)做出只屬於他的消費方案，即因該推送甚麼樣的資訊給該(用戶)，並迫使該(用戶)買單
# 2.Apple App Store數據、Google Play商店應用的對應數據...等等
# 3.數值、表格、曲線圖
# 4.A.大部分的消費金額為多少
#   B.該物品瀏覽次數、間格時間
#   C.購買的物品種類以百分比區分
#   D.觀看但未購買的物品種類以百分比區分
#   E.同商品購買價格
#   F.同商品同價格敘述差異、及圖片

# %% [markdown]
# 作業2
# 1.提申載客率、降低空車時間、降低代數時間
# 2.可排班的地點、GOOGLE平日及假日尖峰地點數據、從車隊系統統計最長叫車的地點
# 3.文字、數字、地形、座標、表格、曲線圖
# 4.平均怠速時間、平均空車時間、平均排班時間、平均尖峰時間、平均距離、平均載客時間、平均載客率

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, yp):    #Mean Square Error 均方誤差
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse
def mean_absolute_error(y, yp):   #mean absolute error 平均絕對誤差
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 260.704
# The Mean absolute error is 12.917
